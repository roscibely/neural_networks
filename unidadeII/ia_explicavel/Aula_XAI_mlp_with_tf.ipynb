# %% [markdown]
# # Exemplo - Multilayer Perceptron com TensorFlow
#
# ### Problema: Classificação de flores Iris
#
# Atributos presentes no dataset:
# 1. comprimento da sépala em cm
# 2. largura da sépala em cm
# 3. comprimento da pétala em 'cm
# 4. largura da pétala em cm
# 5. classe:
#     - Iris Setosa
#     - Iris Versicolor
#     - Iris Virgínia
#
# #### Objetivo: Classificar uma flor Iris com base em suas medidas
#
#
# <div>
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/5/56/Kosaciec_szczecinkowaty_Iris_setosa.jpg/1200px-Kosaciec_szczecinkowaty_Iris_setosa.jpg" width="200" height="200" />
# <img src="https://upload.wikimedia.org/wikipedia/commons/2/27/Blue_Flag%2C_Ottawa.jpg" width="200" height="200" />
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/f/f8/Iris_virginica_2.jpg/1200px-Iris_virginica_2.jpg" width="200" height="200" /> </div>
#
#  Iris Setosa, Iris Versicolor, Iris Virginica, respectivamente.

# %% [markdown]
# ## 1. Importando bibliotecas

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %% [markdown]
# ## 2. Carregando dataset

# %%
df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data', header=None)

# %%
df.head()
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       150 non-null    float64
#  1   1       150 non-null    float64
#  2   2       150 non-null    float64
#  3   3       150 non-null    float64
#  4   4       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df = df.dropna()

df[df == '?'].count()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# dtype: int64

# %% [markdown]
# ### 2.1. Visualizando as 5 primeiras linhas do dataset

# %%
lista =['comprimento_sepala', 'largura_sepala', 'comprimento_petala', 'largura_petala', 'classe']
df.columns = lista

df.head(5)
# Out:
#    comprimento_sepala  largura_sepala  comprimento_petala  largura_petala  \
# 0                 5.1             3.5                 1.4             0.2
# 1                 4.9             3.0                 1.4             0.2
# 2                 4.7             3.2                 1.3             0.2
# 3                 4.6             3.1                 1.5             0.2
# 4                 5.0             3.6                 1.4             0.2
#
#         classe
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %%
df['classe'] = df['classe'].astype('category').cat.codes

# %%
input_train, input_test, output_train, output_test = train_test_split(df.iloc[:,0:4], df['classe'], test_size=0.2)

# %%
input_train = pd.DataFrame(input_train)
input_train.to_csv('input_train.csv', index=False)

input_test = pd.DataFrame(input_test)
input_test.to_csv('input_test.csv', index=False)

output_train = pd.DataFrame(output_train)
output_train.to_csv('output_train.csv', index=False)

output_test = pd.DataFrame(output_test)
output_test.to_csv('output_test.csv', index=False)

# %%
## Carregar os dados de treino

input_train = pd.read_csv('input_train.csv')
output_train = pd.read_csv('output_train.csv')

# %% [markdown]
# ## Balanceamento do dados com SMOTE

# %%
## Balancemento dos dados com SMOTE
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=42)

input_train_balanced, output_train_balanced = sm.fit_resample(input_train, output_train)

# %%
# Salvar dados balanceados
input_train_balanced.to_csv('input_train_balanced.csv', index=False)
output_train_balanced.to_csv('output_train_balanced.csv', index=False)

# %%
output_train_balanced.value_counts()
# Out:
# classe
# 0         41
# 1         41
# 2         41
# Name: count, dtype: int64

# %% [markdown]
# ### 2.2. Dividindo o dataset em atributos e classes

# %%
classes = df['classe'].unique()

# %%
print(classes)
# Out:
# [0 1 2]

# %%
X = df.iloc[:, 0:4].values # Atributos/Features
y = df['classe'].values # Classes/Labels

# %% [markdown]
# ## 3. Dividindo o dataset em treino e teste

# %%
# Dividindo os dados em treino e teste em 80% e 20% respectivamente
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Padronizando os dados de entrada (X) para média 0 e desvio padrão 1
sc = StandardScaler()
sc.fit(X_train)
X_train_std = sc.fit_transform(X_train)
X_test_std = sc.transform(X_test)
# Convertendo as classes em valores numéricos
# Uma classe será representada por um vetor de 3 posições, onde apenas uma posição será 1 e as outras 0
# Exemplo: Iris-setosa = [1, 0, 0]
#          Iris-versicolor = [0, 1, 0]
#          Iris-virginica = [0, 0, 1]
# Fazemos isso, pois o algoritmo de aprendizado de máquina espera os dados sejam representadas por valores numéricos
y_train_onehot = pd.get_dummies(y_train).values
y_test_onehot = pd.get_dummies(y_test).values

# %% [markdown]
# ## 4. Criando o modelo

# %% [markdown]
# Documentação
#
# https://keras.io/api/layers/activations/ |
# https://keras.io/api/layers/core_layers/dense/ |
# https://keras.io/api/optimizers/

# %%
# Modelo de rede perceptron multicamadas com uma camada oculta de 64 neurônios
# e camada de saída com 3 neurônios (3 classes)
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(64, input_dim=4, activation='sigmoid', name='oculta'))
model.add(tf.keras.layers.Dense(3, activation='softmax', name='saida'))
model.summary() #visualizando o modelo
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ oculta (Dense)                       │ (None, 64)                  │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ saida (Dense)                        │ (None, 3)                   │             195 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 515 (2.01 KB)
#  Trainable params: 515 (2.01 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### 4.1. Compilando o modelo

# %%
# Compile model
# Otimizador Adam com taxa de aprendizado de 0.01
opt = tf.keras.optimizers.Adam(learning_rate=0.01)
# Função de custo categorical_crossentropy (para problemas de classificação com mais de duas classes)
# Métrica de avaliação MSE (Mean Squared Error)
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['mse'])

# %% [markdown]
# ### 4.2. Treinando o modelo

# %%
# Train model
history = model.fit(X_train_std, y_train_onehot, validation_split=0.2, epochs=100)
# Out:
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 619ms/step - loss: 1.2005 - mse: 0.2467 - val_loss: 1.0648 - val_mse: 0.2161
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 1.0163 - mse: 0.2056 - val_loss: 0.8925 - val_mse: 0.1776
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.8947 - mse: 0.1782 - val_loss: 0.7288 - val_mse: 0.1356
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.7795 - mse: 0.1483 - val_loss: 0.6053 - val_mse: 0.1063
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 0.7013 - mse: 0.1310 - val_loss: 0.5276 - val_mse: 0.0918
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 165ms/step - loss: 0.6088 - mse: 0.1136 - val_loss: 0.4796 - val_mse: 0.0845
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.5398 - mse: 0.1005 - val_loss: 0.4257 - val_mse: 0.0746
# Epoch 8/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.5057 - mse: 0.0947 - val_loss: 0.3660 - val_mse: 0.0628
# Epoch 9/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.4553 - mse: 0.0846 - val_loss: 0.3263 - val_mse: 0.0565
# Epoch 10/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.4263 - mse: 0.0810 - val_loss: 0.2999 - val_mse: 0.0527
# Epoch 11/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.3873 - mse: 0.0727 - val_loss: 0.2901 - val_mse: 0.0513
# Epoch 12/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.3783 - mse: 0.0712 - val_loss: 0.2910 - val_mse: 0.0525
# Epoch 13/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.3374 - mse: 0.0626 - val_loss: 0.2696 - val_mse: 0.0485
# Epoch 14/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.3333 - mse: 0.0641 - val_loss: 0.2440 - val_mse: 0.0441
# Epoch 15/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.3276 - mse: 0.0608 - val_loss: 0.2318 - val_mse: 0.0423
# Epoch 16/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.3033 - mse: 0.0576 - val_loss: 0.2299 - val_mse: 0.0416
# Epoch 17/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2821 - mse: 0.0522 - val_loss: 0.2245 - val_mse: 0.0406
# Epoch 18/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.2608 - mse: 0.0470 - val_loss: 0.2242 - val_mse: 0.0404
# Epoch 19/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.2591 - mse: 0.0483 - val_loss: 0.2186 - val_mse: 0.0394
# Epoch 20/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.2393 - mse: 0.0424 - val_loss: 0.2133 - val_mse: 0.0384
# Epoch 21/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.2331 - mse: 0.0420 - val_loss: 0.2024 - val_mse: 0.0366
# Epoch 22/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.2284 - mse: 0.0410 - val_loss: 0.1898 - val_mse: 0.0345
# Epoch 23/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.1995 - mse: 0.0340 - val_loss: 0.1850 - val_mse: 0.0336
# Epoch 24/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.1991 - mse: 0.0348 - val_loss: 0.1853 - val_mse: 0.0335
# Epoch 25/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.1965 - mse: 0.0337 - val_loss: 0.1866 - val_mse: 0.0337
# Epoch 26/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.2010 - mse: 0.0349 - val_loss: 0.1767 - val_mse: 0.0320
# Epoch 27/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1874 - mse: 0.0326 - val_loss: 0.1672 - val_mse: 0.0303
# Epoch 28/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.1707 - mse: 0.0280 - val_loss: 0.1601 - val_mse: 0.0291
# Epoch 29/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.1715 - mse: 0.0285 - val_loss: 0.1532 - val_mse: 0.0278
# Epoch 30/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.1869 - mse: 0.0325 - val_loss: 0.1536 - val_mse: 0.0280
# Epoch 31/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.1588 - mse: 0.0257 - val_loss: 0.1508 - val_mse: 0.0276
# Epoch 32/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.1612 - mse: 0.0266 - val_loss: 0.1465 - val_mse: 0.0269
# Epoch 33/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.1693 - mse: 0.0284 - val_loss: 0.1383 - val_mse: 0.0253
# Epoch 34/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.1419 - mse: 0.0221 - val_loss: 0.1307 - val_mse: 0.0238
# Epoch 35/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.1428 - mse: 0.0221 - val_loss: 0.1271 - val_mse: 0.0233
# Epoch 36/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.1236 - mse: 0.0183 - val_loss: 0.1245 - val_mse: 0.0229
# Epoch 37/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.1229 - mse: 0.0178 - val_loss: 0.1236 - val_mse: 0.0229
# Epoch 38/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1289 - mse: 0.0190 - val_loss: 0.1186 - val_mse: 0.0219
# Epoch 39/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.1396 - mse: 0.0229 - val_loss: 0.1156 - val_mse: 0.0215
# Epoch 40/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1121 - mse: 0.0162 - val_loss: 0.1111 - val_mse: 0.0206
# Epoch 41/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1334 - mse: 0.0208 - val_loss: 0.0998 - val_mse: 0.0180
# Epoch 42/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1291 - mse: 0.0202 - val_loss: 0.0979 - val_mse: 0.0177
# Epoch 43/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.1171 - mse: 0.0171 - val_loss: 0.1005 - val_mse: 0.0187
# Epoch 44/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.1183 - mse: 0.0181 - val_loss: 0.1015 - val_mse: 0.0192
# Epoch 45/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.1070 - mse: 0.0155 - val_loss: 0.0989 - val_mse: 0.0187
# Epoch 46/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0926 - mse: 0.0137 - val_loss: 0.0925 - val_mse: 0.0172
# Epoch 47/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0936 - mse: 0.0129 - val_loss: 0.0856 - val_mse: 0.0156
# Epoch 48/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.1042 - mse: 0.0159 - val_loss: 0.0805 - val_mse: 0.0143
# Epoch 49/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1012 - mse: 0.0149 - val_loss: 0.0812 - val_mse: 0.0147
# Epoch 50/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1158 - mse: 0.0187 - val_loss: 0.0871 - val_mse: 0.0165
# Epoch 51/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0977 - mse: 0.0150 - val_loss: 0.0853 - val_mse: 0.0162
# Epoch 52/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0962 - mse: 0.0147 - val_loss: 0.0809 - val_mse: 0.0152
# Epoch 53/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.1051 - mse: 0.0171 - val_loss: 0.0759 - val_mse: 0.0139
# Epoch 54/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0807 - mse: 0.0115 - val_loss: 0.0691 - val_mse: 0.0121
# Epoch 55/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0770 - mse: 0.0112 - val_loss: 0.0699 - val_mse: 0.0125
# Epoch 56/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0847 - mse: 0.0124 - val_loss: 0.0680 - val_mse: 0.0121
# Epoch 57/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0782 - mse: 0.0122 - val_loss: 0.0694 - val_mse: 0.0126
# Epoch 58/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0838 - mse: 0.0133 - val_loss: 0.0719 - val_mse: 0.0134
# Epoch 59/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0737 - mse: 0.0101 - val_loss: 0.0675 - val_mse: 0.0123
# Epoch 60/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0776 - mse: 0.0115 - val_loss: 0.0641 - val_mse: 0.0115
# Epoch 61/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0887 - mse: 0.0143 - val_loss: 0.0587 - val_mse: 0.0101
# Epoch 62/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0753 - mse: 0.0115 - val_loss: 0.0616 - val_mse: 0.0110
# Epoch 63/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0784 - mse: 0.0122 - val_loss: 0.0632 - val_mse: 0.0116
# Epoch 64/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0650 - mse: 0.0088 - val_loss: 0.0654 - val_mse: 0.0123
# Epoch 65/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0858 - mse: 0.0138 - val_loss: 0.0634 - val_mse: 0.0118
# Epoch 66/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 0.0691 - mse: 0.0106 - val_loss: 0.0612 - val_mse: 0.0113
# Epoch 67/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0556 - mse: 0.0077 - val_loss: 0.0542 - val_mse: 0.0094
# Epoch 68/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0682 - mse: 0.0104 - val_loss: 0.0527 - val_mse: 0.0090
# Epoch 69/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0638 - mse: 0.0101 - val_loss: 0.0563 - val_mse: 0.0101
# Epoch 70/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0601 - mse: 0.0087 - val_loss: 0.0545 - val_mse: 0.0097
# Epoch 71/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0742 - mse: 0.0124 - val_loss: 0.0558 - val_mse: 0.0101
# Epoch 72/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0791 - mse: 0.0135 - val_loss: 0.0596 - val_mse: 0.0112
# Epoch 73/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0610 - mse: 0.0088 - val_loss: 0.0524 - val_mse: 0.0093
# Epoch 74/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0657 - mse: 0.0107 - val_loss: 0.0504 - val_mse: 0.0088
# Epoch 75/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0591 - mse: 0.0092 - val_loss: 0.0489 - val_mse: 0.0084
# Epoch 76/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0711 - mse: 0.0119 - val_loss: 0.0491 - val_mse: 0.0085
# Epoch 77/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0625 - mse: 0.0101 - val_loss: 0.0508 - val_mse: 0.0090
# Epoch 78/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0613 - mse: 0.0103 - val_loss: 0.0530 - val_mse: 0.0097
# Epoch 79/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0594 - mse: 0.0093 - val_loss: 0.0521 - val_mse: 0.0095
# Epoch 80/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0667 - mse: 0.0105 - val_loss: 0.0506 - val_mse: 0.0091
# Epoch 81/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0549 - mse: 0.0085 - val_loss: 0.0466 - val_mse: 0.0081
# Epoch 82/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0671 - mse: 0.0110 - val_loss: 0.0466 - val_mse: 0.0081
# Epoch 83/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0522 - mse: 0.0081 - val_loss: 0.0496 - val_mse: 0.0090
# Epoch 84/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0511 - mse: 0.0077 - val_loss: 0.0474 - val_mse: 0.0084
# Epoch 85/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0627 - mse: 0.0112 - val_loss: 0.0493 - val_mse: 0.0090
# Epoch 86/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0688 - mse: 0.0119 - val_loss: 0.0450 - val_mse: 0.0079
# Epoch 87/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0632 - mse: 0.0111 - val_loss: 0.0425 - val_mse: 0.0072
# Epoch 88/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0610 - mse: 0.0106 - val_loss: 0.0435 - val_mse: 0.0075
# Epoch 89/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0531 - mse: 0.0094 - val_loss: 0.0458 - val_mse: 0.0082
# Epoch 90/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0605 - mse: 0.0109 - val_loss: 0.0502 - val_mse: 0.0094
# Epoch 91/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0491 - mse: 0.0079 - val_loss: 0.0494 - val_mse: 0.0092
# Epoch 92/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0634 - mse: 0.0110 - val_loss: 0.0446 - val_mse: 0.0079
# Epoch 93/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0582 - mse: 0.0098 - val_loss: 0.0361 - val_mse: 0.0057
# Epoch 94/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0535 - mse: 0.0086 - val_loss: 0.0355 - val_mse: 0.0055
# Epoch 95/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0541 - mse: 0.0090 - val_loss: 0.0400 - val_mse: 0.0068
# Epoch 96/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0682 - mse: 0.0130 - val_loss: 0.0533 - val_mse: 0.0104
# Epoch 97/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0425 - mse: 0.0064 - val_loss: 0.0534 - val_mse: 0.0105
# Epoch 98/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0574 - mse: 0.0099 - val_loss: 0.0444 - val_mse: 0.0080
# Epoch 99/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0509 - mse: 0.0086 - val_loss: 0.0391 - val_mse: 0.0066
# Epoch 100/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0474 - mse: 0.0077 - val_loss: 0.0359 - val_mse: 0.0058

# %% [markdown]
# ## 5. Visualizando o erro

# %%
# Plot training & validation accuracy values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
#plt.yscale("log")
plt.title('Função Perda')
plt.ylabel('MSE')
plt.xlabel('Epocas')
plt.legend(['Treino'], loc='upper left')
plt.show()

# %% [markdown]
# ## 6. Métricas: Avaliação do modelo

# %%
output_model_ = np.argmax(model.predict(X_test_std), axis=-1)
y_test_class = np.argmax(y_test_onehot, axis=-1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step

# %%
cm = confusion_matrix(y_test_class, output_model_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
disp.ax_.set_title('Matriz de confusão')
disp.ax_.set_xlabel('Classificação prevista')
disp.ax_.set_ylabel('Classificação real')
plt.show()

# %% [markdown]
# ## 7. Testando o modelo

# %%
comprimento_sepala=5.1
largura_sepala=3.5
comprimento_petala=1.4
largura_petala=0.2
teste = np.array([[comprimento_sepala, 	largura_sepala, 	comprimento_petala, 	largura_petala]])
teste = sc.transform(teste)

"""
    1 - Iris-setosa
    2 - Iris-versicolor
    3 - Iris-virginica
"""
y_predd = model.predict(teste)
y_predd = np.argmax(y_predd, axis=1)

print("A classe é:", classes[y_predd[-1]])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# A classe é: 0

# %% [markdown]
# # 8. Explicando o modelo

# %%
# !pip install shap
# Out:
# Collecting shap
#   Downloading shap-0.46.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (24 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from shap) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from shap) (1.13.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from shap) (1.3.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from shap) (2.1.4)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.10/dist-packages (from shap) (4.66.4)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.10/dist-packages (from shap) (24.1)
# Collecting slicer==0.0.8 (from shap)
#   Downloading slicer-0.0.8-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from shap) (0.60.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from shap) (2.2.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->shap) (0.43.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2024.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->shap) (1.16.0)
# Downloading shap-0.46.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (540 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 540.1/540.1 kB 14.5 MB/s eta 0:00:00
# Downloading slicer-0.0.8-py3-none-any.whl (15 kB)
# Installing collected packages: slicer, shap
# Successfully installed shap-0.46.0 slicer-0.0.8

# %%
import shap

# %%
def model_predict(X):
    return np.argmax(model.predict(X), axis=-1)

# %%
explainer = shap.KernelExplainer(model_predict, X_test_std)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step

# %%
shap_values = explainer.shap_values(X_test_std)
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
shap.summary_plot(shap_values, X_test_std,  feature_names=lista)

# %%
shap.summary_plot(shap_values, X_test_std,  feature_names=lista, plot_type="bar")

# %%
shap.initjs()
shap.force_plot(explainer.expected_value, shap_values, X_test_std)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# <div id='iL61BOBNP7BGTCKWB8IV1'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["f(x)"], "baseValue": 1.0000000000000002, "link": "identity", "featureNames": ["Feature 0", "Feature 1", "Feature 2", "Feature 3"], "explanations": [{"outValue": 2.0, "simIndex": 21.0, "features": {"0": {"effect": 0.05000000000000007, "value": 0.17738263723581418}, "1": {"effect": 0.5000000000000002, "value": -1.922531276298921}, "2": {"effect": 0.28888888888888853, "value": 0.7122743498760014}, "3": {"effect": 0.16111111111111098, "value": 0.401955069167019}}}, {"outValue": 1.0, "simIndex": 19.0, "features": {"0": {"effect": 0.044444444444444384, "value": -0.060448831683715905}, "1": {"effect": 0.10555555555555554, "value": -1.031783194616023}, "2": {"effect": 0.038888888888888855, "value": 0.14510167578761274}, "3": {"effect": -0.188888888888889, "value": 0.004417088672164854}}}, {"outValue": 0.0, "simIndex": 9.0, "features": {"0": {"effect": -0.063888888888889, "value": -0.8928589729020707}, "1": {"effect": -0.2638888888888889, "value": 1.6404610504326713}, "2": {"effect": -0.34166666666666673, "value": -1.2161127420245197}, "3": {"effect": -0.3305555555555556, "value": -1.320709512977349}}}, {"outValue": 0.0, "simIndex": 3.0, "features": {"0": {"effect": -0.15000000000000005, "value": -1.7252691141204244}, "1": {"effect": -0.022222222222222265, "value": -0.3637221333538496}, "2": {"effect": -0.4388888888888891, "value": -1.3295472768421974}, "3": {"effect": -0.38888888888888884, "value": -1.320709512977349}}}, {"outValue": 2.0, "simIndex": 23.0, "features": {"0": {"effect": 0.0750000000000001, "value": 0.6530455750748744}, "1": {"effect": -0.0027777777777777788, "value": 0.0816519074875999}, "2": {"effect": 0.4527777777777776, "value": 0.9958606869201956}, "3": {"effect": 0.47499999999999987, "value": 0.7994930496618732}}}, {"outValue": 0.0, "simIndex": 5.0, "features": {"0": {"effect": -0.16666666666666677, "value": -1.7252691141204244}, "1": {"effect": -0.08333333333333348, "value": 0.3043389279083247}, "2": {"effect": -0.4111111111111111, "value": -1.3862645442510364}, "3": {"effect": -0.3388888888888889, "value": -1.320709512977349}}}, {"outValue": 1.0, "simIndex": 15.0, "features": {"0": {"effect": 0.08888888888888885, "value": 1.009792778454169}, "1": {"effect": 0.011111111111111082, "value": 0.0816519074875999}, "2": {"effect": 0.027777777777777755, "value": 0.3719707454229684}, "3": {"effect": -0.1277777777777779, "value": 0.26944240900206756}}}, {"outValue": 1.0, "simIndex": 16.0, "features": {"0": {"effect": 0.05277777777777776, "value": 0.5341298406151088}, "1": {"effect": 0.0027777777777777046, "value": -0.5864091537745744}, "2": {"effect": 0.04166666666666668, "value": 0.76899161728484}, "3": {"effect": -0.09722222222222236, "value": 0.401955069167019}}}, {"outValue": 1.0, "simIndex": 20.0, "features": {"0": {"effect": 0.019444444444444393, "value": -0.4171960350630105}, "1": {"effect": 0.16388888888888883, "value": -1.4771572354574725}, "2": {"effect": 0.013888888888888883, "value": 0.03166714096993494}, "3": {"effect": -0.19722222222222235, "value": -0.12809557149278633}}}, {"outValue": 2.0, "simIndex": 22.0, "features": {"0": {"effect": 0.05555555555555564, "value": 0.5341298406151088}, "1": {"effect": 0.055555555555555546, "value": -0.3637221333538496}, "2": {"effect": 0.4666666666666665, "value": 1.0525779543290343}, "3": {"effect": 0.42222222222222205, "value": 0.7994930496618732}}}, {"outValue": 1.0, "simIndex": 13.0, "features": {"0": {"effect": 0.05833333333333332, "value": 0.05846690277604968}, "1": {"effect": 0.0472222222222222, "value": -0.14103511293312487}, "2": {"effect": -0.05277777777777785, "value": 0.2585362106052906}, "3": {"effect": -0.05277777777777789, "value": 0.401955069167019}}}, {"outValue": 1.0, "simIndex": 17.0, "features": {"0": {"effect": 0.055555555555555525, "value": 0.2962983716955787}, "1": {"effect": 0.06666666666666667, "value": -0.5864091537745744}, "2": {"effect": 0.1111111111111111, "value": 0. ...
